# %%
import tensorflow as tf
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %% [markdown]
# # 训练参数问题：trainable
#    * 决定你在训练过程中参数是否可变
#
# # 学习率和步数设置
#    * tf.train.GradientDescentOptimizer(0.1)
#        * 学习率太大会导致训练结果误差太大
#        * 同时也会影响到学习的步数
#
#    * 在极端情况下，权重的值变得非常大，以至于溢出，导致NaN值
# ## 解决问题
#        * 1.重新设计网络
#        * 2.调整学习率
#        * 3.使用梯度截断（在训练过程中检查和限制梯度的大小）
#        * 4.使用激活函数

# %%
def myregression1():
    """
    线性回归预测
    """
    
    #1.准备数据 x：特征值【100,1】 y：目标值【100】
    x = tf.random_normal([100,1],mean=1.75,stddev=0.5,name='x_data')

    #矩阵相乘必须是二维的（预设好的数据）
    y_true = tf.matmul(x,[[0.7]]) + 0.8
    
    #2.建立线性回归模型 1个特征，1个权重  一个偏置 y= x*w + b
    #随机给一个权重和偏置的值，去计算损失，然后在当前状态下优化
    #用变量定义才能优化（数据可变）
    #trainable决定训练过程中的值是否被改变
    weight = tf.Variable(
        tf.random_normal([1,1],mean=0.0,stddev=1.0),
        name='w',
        trainable=True
    )
    
    
    bias = tf.Variable(
        0.0,
        name='b',
        trainable=True
    )
    y_predict = tf.matmul(x,weight) + bias
    
    #3.建立损失函数，均分误差
    loss = tf.reduce_mean(tf.square(y_true - y_predict))
    
    #4.梯度下降优化损失:leaning_rate：0~1，2,3...
    train_op = tf.train.GradientDescentOptimizer(0.1).minimize(loss)
    
    #定义一个初始化变量的op
    init_op = tf.global_variables_initializer()
    
    #通过会话运行程序
    with tf.Session() as sess:
        #初始化变量
        sess.run(init_op)
        
        #打印随机最先初始化的权重和偏置
        print("随机初始化的参数权重：%f,偏置为：%f" %(weight.eval(),bias.eval() ))
        
        #建立事件文件
        fileWriter = tf.summary.FileWriter('./summary/',graph=sess.graph)
        
        #循环训练，运行优化
        for i in range(200):
            sess.run(train_op)
            print("第%d次优化的参数权重：%f,偏置为：%f" %(i,weight.eval(),bias.eval() ))
        
        
myregression1()
# Out:
# 随机初始化的参数权重：0.518544,偏置为：0.000000
# 第0次优化的参数权重：0.922748,偏置为：0.224117
# 第1次优化的参数权重：0.980659,偏置为：0.263653
# 第2次优化的参数权重：0.982259,偏置为：0.271975
# 第3次优化的参数权重：0.976425,偏置为：0.277254
# 第4次优化的参数权重：0.975374,偏置为：0.283694
# 第5次优化的参数权重：0.973736,偏置为：0.291567
# 第6次优化的参数权重：0.968410,偏置为：0.295210
# 第7次优化的参数权重：0.965288,偏置为：0.301872
# 第8次优化的参数权重：0.965738,偏置为：0.309954
# 第9次优化的参数权重：0.961791,偏置为：0.313587
# 第10次优化的参数权重：0.960776,偏置为：0.321359
# 第11次优化的参数权重：0.950439,偏置为：0.323262
# 第12次优化的参数权重：0.953016,偏置为：0.331072
# 第13次优化的参数权重：0.949341,偏置为：0.335632
# 第14次优化的参数权重：0.942202,偏置为：0.340055
# 第15次优化的参数权重：0.941453,偏置为：0.345515
# 第16次优化的参数权重：0.941202,偏置为：0.350676
# 第17次优化的参数权重：0.946031,偏置为：0.361681
# 第18次优化的参数权重：0.939659,偏置为：0.364452
# 第19次优化的参数权重：0.937218,偏置为：0.369839
# 第20次优化的参数权重：0.930589,偏置为：0.373527
# 第21次优化的参数权重：0.929957,偏置为：0.379253
# 第22次优化的参数权重：0.930942,偏置为：0.385848
# 第23次优化的参数权重：0.919942,偏置为：0.385224
# 第24次优化的参数权重：0.924065,偏置为：0.392051
# 第25次优化的参数权重：0.918091,偏置为：0.394302
# 第26次优化的参数权重：0.920832,偏置为：0.402369
# 第27次优化的参数权重：0.908099,偏置为：0.402299
# 第28次优化的参数权重：0.911634,偏置为：0.409975
# 第29次优化的参数权重：0.912941,偏置为：0.417344
# 第30次优化的参数权重：0.910824,偏置为：0.422386
# 第31次优化的参数权重：0.904074,偏置为：0.424873
# 第32次优化的参数权重：0.901027,偏置为：0.428212
# 第33次优化的参数权重：0.900173,偏置为：0.434364
# 第34次优化的参数权重：0.891198,偏置为：0.434693
# 第35次优化的参数权重：0.890206,偏置为：0.439754
# 第36次优化的参数权重：0.885261,偏置为：0.441685
# 第37次优化的参数权重：0.890723,偏置为：0.449825
# 第38次优化的参数权重：0.884279,偏置为：0.451331
# 第39次优化的参数权重：0.882005,偏置为：0.457066
# 第40次优化的参数权重：0.882255,偏置为：0.462335
# 第41次优化的参数权重：0.882066,偏置为：0.467141
# 第42次优化的参数权重：0.881176,偏置为：0.471454
# 第43次优化的参数权重：0.875413,偏置为：0.473451
# 第44次优化的参数权重：0.867578,偏置为：0.474661
# 第45次优化的参数权重：0.875781,偏置为：0.484408
# 第46次优化的参数权重：0.867158,偏置为：0.483737
# 第47次优化的参数权重：0.869650,偏置为：0.488774
# 第48次优化的参数权重：0.864350,偏置为：0.491043
# 第49次优化的参数权重：0.864184,偏置为：0.494587
# 第50次优化的参数权重：0.858360,偏置为：0.496568
# 第51次优化的参数权重：0.855834,偏置为：0.500217
# 第52次优化的参数权重：0.860459,偏置为：0.507047
# 第53次优化的参数权重：0.857139,偏置为：0.508441
# 第54次优化的参数权重：0.856054,偏置为：0.512606
# 第55次优化的参数权重：0.847941,偏置为：0.513277
# 第56次优化的参数权重：0.849412,偏置为：0.518813
# 第57次优化的参数权重：0.850625,偏置为：0.523353
# 第58次优化的参数权重：0.852601,偏置为：0.528225
# 第59次优化的参数权重：0.846490,偏置为：0.529214
# 第60次优化的参数权重：0.845812,偏置为：0.533374
# 第61次优化的参数权重：0.839392,偏置为：0.533978
# 第62次优化的参数权重：0.841455,偏置为：0.539247
# 第63次优化的参数权重：0.839765,偏置为：0.541563
# 第64次优化的参数权重：0.838358,偏置为：0.543884
# 第65次优化的参数权重：0.836454,偏置为：0.546274
# 第66次优化的参数权重：0.837677,偏置为：0.551352
# 第67次优化的参数权重：0.833484,偏置为：0.552844
# 第68次优化的参数权重：0.833565,偏置为：0.557382
# 第69次优化的参数权重：0.831430,偏置为：0.560718
# 第70次优化的参数权重：0.828198,偏置为：0.562276
# 第71次优化的参数权重：0.830619,偏置为：0.567451
# 第72次优化的参数权重：0.826926,偏置为：0.568894
# 第73次优化的参数权重：0.821266,偏置为：0.569996
# 第74次优化的参数权重：0.821636,偏置为：0.573663
# 第75次优化的参数权重：0.822364,偏置为：0.576995
# 第76次优化的参数权重：0.818804,偏置为：0.578114
# 第77次优化的参数权重：0.818003,偏置为：0.580909
# 第78次优化的参数权重：0.818730,偏置为：0.584985
# 第79次优化的参数权重：0.814763,偏置为：0.585762
# 第80次优化的参数权重：0.814397,偏置为：0.589296
# 第81次优化的参数权重：0.812776,偏置为：0.592276
# 第82次优化的参数权重：0.814409,偏置为：0.596442
# 第83次优化的参数权重：0.814810,偏置为：0.599829
# 第84次优化的参数权重：0.805724,偏置为：0.598405
# 第85次优化的参数权重：0.810181,偏置为：0.604227
# 第86次优化的参数权重：0.803390,偏置为：0.602940
# 第87次优化的参数权重：0.804435,偏置为：0.606126
# 第88次优化的参数权重：0.799314,偏置为：0.606225
# 第89次优化的参数权重：0.799801,偏置为：0.609575
# 第90次优化的参数权重：0.798390,偏置为：0.611422
# 第91次优化的参数权重：0.798738,偏置为：0.614026
# 第92次优化的参数权重：0.797030,偏置为：0.615599
# 第93次优化的参数权重：0.798405,偏置为：0.619181
# 第94次优化的参数权重：0.798251,偏置为：0.621510
# 第95次优化的参数权重：0.795791,偏置为：0.623077
# 第96次优化的参数权重：0.793591,偏置为：0.624369
# 第97次优化的参数权重：0.793772,偏置为：0.626473
# 第98次优化的参数权重：0.792703,偏置为：0.627920
# 第99次优化的参数权重：0.792706,偏置为：0.630769
# 第100次优化的参数权重：0.788082,偏置为：0.630036
# 第101次优化的参数权重：0.786379,偏置为：0.632262
# 第102次优化的参数权重：0.788354,偏置为：0.635675
# 第103次优化的参数权重：0.787895,偏置为：0.637709
# 第104次优化的参数权重：0.785636,偏置为：0.639069
# 第105次优化的参数权重：0.781498,偏置为：0.639471
# 第106次优化的参数权重：0.781038,偏置为：0.641708
# 第107次优化的参数权重：0.782596,偏置为：0.644870
# 第108次优化的参数权重：0.778677,偏置为：0.645219
# 第109次优化的参数权重：0.782182,偏置为：0.649175
# 第110次优化的参数权重：0.783445,偏置为：0.652293
# 第111次优化的参数权重：0.778572,偏置为：0.652258
# 第112次优化的参数权重：0.779185,偏置为：0.654998
# 第113次优化的参数权重：0.779529,偏置为：0.657528
# 第114次优化的参数权重：0.776347,偏置为：0.658303
# 第115次优化的参数权重：0.776660,偏置为：0.660718
# 第116次优化的参数权重：0.775049,偏置为：0.662116
# 第117次优化的参数权重：0.774425,偏置为：0.663508
# 第118次优化的参数权重：0.773286,偏置为：0.664950
# 第119次优化的参数权重：0.771406,偏置为：0.665811
# 第120次优化的参数权重：0.771578,偏置为：0.667997
# 第121次优化的参数权重：0.770817,偏置为：0.669246
# 第122次优化的参数权重：0.770360,偏置为：0.671127
# 第123次优化的参数权重：0.769305,偏置为：0.672905
# 第124次优化的参数权重：0.768433,偏置为：0.674576
# 第125次优化的参数权重：0.766063,偏置为：0.675477
# 第126次优化的参数权重：0.766898,偏置为：0.677440
# 第127次优化的参数权重：0.766415,偏置为：0.678871
# 第128次优化的参数权重：0.764109,偏置为：0.679364
# 第129次优化的参数权重：0.763586,偏置为：0.680945
# 第130次优化的参数权重：0.763938,偏置为：0.682901
# 第131次优化的参数权重：0.763086,偏置为：0.684895
# 第132次优化的参数权重：0.761618,偏置为：0.685742
# 第133次优化的参数权重：0.760840,偏置为：0.686967
# 第134次优化的参数权重：0.761835,偏置为：0.688982
# 第135次优化的参数权重：0.759959,偏置为：0.689468
# 第136次优化的参数权重：0.759146,偏置为：0.690722
# 第137次优化的参数权重：0.758880,偏置为：0.692397
# 第138次优化的参数权重：0.757267,偏置为：0.693193
# 第139次优化的参数权重：0.757046,偏置为：0.694973
# 第140次优化的参数权重：0.755907,偏置为：0.695748
# 第141次优化的参数权重：0.754667,偏置为：0.696536
# 第142次优化的参数权重：0.755320,偏置为：0.698213
# 第143次优化的参数权重：0.754173,偏置为：0.699329
# 第144次优化的参数权重：0.755208,偏置为：0.701450
# 第145次优化的参数权重：0.754181,偏置为：0.702473
# 第146次优化的参数权重：0.752089,偏置为：0.702635
# 第147次优化的参数权重：0.752347,偏置为：0.704177
# 第148次优化的参数权重：0.752339,偏置为：0.705709
# 第149次优化的参数权重：0.751285,偏置为：0.706468
# 第150次优化的参数权重：0.749183,偏置为：0.706697
# 第151次优化的参数权重：0.749395,偏置为：0.708152
# 第152次优化的参数权重：0.748148,偏置为：0.708597
# 第153次优化的参数权重：0.748020,偏置为：0.709967
# 第154次优化的参数权重：0.748445,偏置为：0.711507
# 第155次优化的参数权重：0.746874,偏置为：0.712223
# 第156次优化的参数权重：0.746407,偏置为：0.713155
# 第157次优化的参数权重：0.746970,偏置为：0.715007
# 第158次优化的参数权重：0.745128,偏置为：0.715448
# 第159次优化的参数权重：0.744403,偏置为：0.716403
# 第160次优化的参数权重：0.744335,偏置为：0.717574
# 第161次优化的参数权重：0.744805,偏置为：0.719006
# 第162次优化的参数权重：0.743161,偏置为：0.719384
# 第163次优化的参数权重：0.744407,偏置为：0.721366
# 第164次优化的参数权重：0.742892,偏置为：0.721534
# 第165次优化的参数权重：0.742167,偏置为：0.722320
# 第166次优化的参数权重：0.741793,偏置为：0.723394
# 第167次优化的参数权重：0.741675,偏置为：0.724473
# 第168次优化的参数权重：0.741098,偏置为：0.725266
# 第169次优化的参数权重：0.738599,偏置为：0.725084
# 第170次优化的参数权重：0.739697,偏置为：0.726666
# 第171次优化的参数权重：0.738470,偏置为：0.727196
# 第172次优化的参数权重：0.738355,偏置为：0.728059
# 第173次优化的参数权重：0.738056,偏置为：0.728968
# 第174次优化的参数权重：0.737947,偏置为：0.730140
# 第175次优化的参数权重：0.737236,偏置为：0.730655
# 第176次优化的参数权重：0.735809,偏置为：0.730970
# 第177次优化的参数权重：0.737504,偏置为：0.732814
# 第178次优化的参数权重：0.736445,偏置为：0.733160
# 第179次优化的参数权重：0.735771,偏置为：0.733722
# 第180次优化的参数权重：0.736719,偏置为：0.735332
# 第181次优化的参数权重：0.734432,偏置为：0.735304
# 第182次优化的参数权重：0.733603,偏置为：0.736036
# 第183次优化的参数权重：0.733775,偏置为：0.737086
# 第184次优化的参数权重：0.734347,偏置为：0.738456
# 第185次优化的参数权重：0.733348,偏置为：0.738947
# 第186次优化的参数权重：0.732905,偏置为：0.739562
# 第187次优化的参数权重：0.731787,偏置为：0.740009
# 第188次优化的参数权重：0.730736,偏置为：0.740247
# 第189次优化的参数权重：0.731394,偏置为：0.741570
# 第190次优化的参数权重：0.731448,偏置为：0.742484
# 第191次优化的参数权重：0.731052,偏置为：0.743018
# 第192次优化的参数权重：0.730330,偏置为：0.743510
# 第193次优化的参数权重：0.730597,偏置为：0.744454
# 第194次优化的参数权重：0.729414,偏置为：0.744709
# 第195次优化的参数权重：0.729769,偏置为：0.745483
# 第196次优化的参数权重：0.729508,偏置为：0.746262
# 第197次优化的参数权重：0.728652,偏置为：0.746495
# 第198次优化的参数权重：0.728794,偏置为：0.747433
# 第199次优化的参数权重：0.728059,偏置为：0.747660

# %% [markdown]
# # 包含作用域
# * 添加作用域
# * 添加权重参数，损失值等在tensorboard观察的情况
#     * 1.收集变量
#     * 2.合并变量写入事件文件

# %%
def myregression2():
    """
    线性回归预测
    """
    
    with tf.variable_scope("data"):
        #1.准备数据 x：特征值【100,1】 y：目标值【100】
        x = tf.random_normal([100,1],mean=1.75,stddev=0.5,name='x_data')

        #矩阵相乘必须是二维的（预设好的数据）
        y_true = tf.matmul(x,[[0.7]]) + 0.8
    
    with tf.variable_scope("model"):
        #2.建立线性回归模型 1个特征，1个权重  一个偏置 y= x*w + b
        #随机给一个权重和偏置的值，去计算损失，然后在当前状态下优化
        #用变量定义才能优化（数据可变）
        #trainable决定训练过程中的值是否被改变
        weight = tf.Variable(tf.random_normal([1,1],mean=0.0,stddev=1.0),name='w',trainable=True)


        bias = tf.Variable(0.0,name='b',trainable=True)
        y_predict = tf.matmul(x,weight) + bias

    
    with tf.variable_scope("loss"):
        #3.建立损失函数，均分误差
        loss = tf.reduce_mean(tf.square(y_true - y_predict))

    with tf.variable_scope("optimizer"):
        #4.梯度下降优化损失:leaning_rate：0~1，2,3...
        train_op = tf.train.GradientDescentOptimizer(0.1).minimize(loss)
    
    #1.收集tensor
    tf.summary.scalar('losses',loss)
    tf.summary.histogram('weights',weight)
    #定义合并tensor的op
    merged = tf.summary.merge_all()
    
    
    #定义一个初始化变量的op
    init_op = tf.global_variables_initializer()
    
    #通过会话运行程序
    with tf.Session() as sess:
        #初始化变量
        sess.run(init_op)
        
        #打印随机最先初始化的权重和偏置
        print("随机初始化的参数权重：%f,偏置为：%f" %(weight.eval(),bias.eval() ))
        
        #建立事件文件
        fileWriter = tf.summary.FileWriter('./summary/',graph=sess.graph)
        
        #循环训练，运行优化
        for i in range(500):
            sess.run(train_op)
            
            #运行合并的tensor(用于tensorboard显示)
            summary = sess.run(merged)
            fileWriter.add_summary(summary,i)
            
            print("第%d次优化的参数权重：%f,偏置为：%f" %(i,weight.eval(),bias.eval() ))

       
        
        
myregression2()
# Out:
# 随机初始化的参数权重：0.668326,偏置为：0.000000
# 第0次优化的参数权重：0.959516,偏置为：0.170744
# 第1次优化的参数权重：1.008501,偏置为：0.206515
# 第2次优化的参数权重：1.007720,偏置为：0.214728
# 第3次优化的参数权重：1.009693,偏置为：0.228538
# 第4次优化的参数权重：0.994029,偏置为：0.229760
# 第5次优化的参数权重：0.995027,偏置为：0.242108
# 第6次优化的参数权重：0.999464,偏置为：0.252973
# 第7次优化的参数权重：0.988155,偏置为：0.257474
# 第8次优化的参数权重：0.983368,偏置为：0.264147
# 第9次优化的参数权重：0.976515,偏置为：0.268479
# 第10次优化的参数权重：0.989306,偏置为：0.283242
# 第11次优化的参数权重：0.980525,偏置为：0.287187
# 第12次优化的参数权重：0.974650,偏置为：0.291573
# 第13次优化的参数权重：0.970582,偏置为：0.295579
# 第14次优化的参数权重：0.966989,偏置为：0.304318
# 第15次优化的参数权重：0.962134,偏置为：0.308437
# 第16次优化的参数权重：0.953683,偏置为：0.311028
# 第17次优化的参数权重：0.955121,偏置为：0.320534
# 第18次优化的参数权重：0.957241,偏置为：0.328833
# 第19次优化的参数权重：0.954684,偏置为：0.336254
# 第20次优化的参数权重：0.953132,偏置为：0.342047
# 第21次优化的参数权重：0.948316,偏置为：0.346507
# 第22次优化的参数权重：0.944186,偏置为：0.351604
# 第23次优化的参数权重：0.941071,偏置为：0.356461
# 第24次优化的参数权重：0.941061,偏置为：0.364720
# 第25次优化的参数权重：0.936288,偏置为：0.368563
# 第26次优化的参数权重：0.933166,偏置为：0.373246
# 第27次优化的参数权重：0.925009,偏置为：0.375917
# 第28次优化的参数权重：0.924984,偏置为：0.382997
# 第29次优化的参数权重：0.919124,偏置为：0.386849
# 第30次优化的参数权重：0.918383,偏置为：0.393573
# 第31次优化的参数权重：0.921221,偏置为：0.401427
# 第32次优化的参数权重：0.915550,偏置为：0.404196
# 第33次优化的参数权重：0.906928,偏置为：0.404816
# 第34次优化的参数权重：0.908634,偏置为：0.414471
# 第35次优化的参数权重：0.910309,偏置为：0.421116
# 第36次优化的参数权重：0.903178,偏置为：0.422558
# 第37次优化的参数权重：0.900436,偏置为：0.426098
# 第38次优化的参数权重：0.899832,偏置为：0.431277
# 第39次优化的参数权重：0.895340,偏置为：0.435630
# 第40次优化的参数权重：0.892908,偏置为：0.440171
# 第41次优化的参数权重：0.889776,偏置为：0.443586
# 第42次优化的参数权重：0.887164,偏置为：0.447439
# 第43次优化的参数权重：0.886101,偏置为：0.451580
# 第44次优化的参数权重：0.894998,偏置为：0.461535
# 第45次优化的参数权重：0.883212,偏置为：0.460705
# 第46次优化的参数权重：0.885891,偏置为：0.466576
# 第47次优化的参数权重：0.881216,偏置为：0.470335
# 第48次优化的参数权重：0.876025,偏置为：0.473020
# 第49次优化的参数权重：0.874212,偏置为：0.476078
# 第50次优化的参数权重：0.869582,偏置为：0.479139
# 第51次优化的参数权重：0.869406,偏置为：0.483919
# 第52次优化的参数权重：0.870044,偏置为：0.488222
# 第53次优化的参数权重：0.869990,偏置为：0.492475
# 第54次优化的参数权重：0.863123,偏置为：0.492404
# 第55次优化的参数权重：0.864385,偏置为：0.498269
# 第56次优化的参数权重：0.864527,偏置为：0.502309
# 第57次优化的参数权重：0.860318,偏置为：0.504601
# 第58次优化的参数权重：0.856753,偏置为：0.508269
# 第59次优化的参数权重：0.852522,偏置为：0.510152
# 第60次优化的参数权重：0.854082,偏置为：0.514977
# 第61次优化的参数权重：0.846798,偏置为：0.515374
# 第62次优化的参数权重：0.849733,偏置为：0.520348
# 第63次优化的参数权重：0.845969,偏置为：0.522564
# 第64次优化的参数权重：0.846473,偏置为：0.526671
# 第65次优化的参数权重：0.845814,偏置为：0.531865
# 第66次优化的参数权重：0.843306,偏置为：0.535367
# 第67次优化的参数权重：0.837214,偏置为：0.535353
# 第68次优化的参数权重：0.838869,偏置为：0.539750
# 第69次优化的参数权重：0.835573,偏置为：0.542016
# 第70次优化的参数权重：0.836278,偏置为：0.546614
# 第71次优化的参数权重：0.834951,偏置为：0.549354
# 第72次优化的参数权重：0.830025,偏置为：0.550783
# 第73次优化的参数权重：0.832195,偏置为：0.555848
# 第74次优化的参数权重：0.831012,偏置为：0.558869
# 第75次优化的参数权重：0.827784,偏置为：0.560602
# 第76次优化的参数权重：0.831120,偏置为：0.565853
# 第77次优化的参数权重：0.824816,偏置为：0.565925
# 第78次优化的参数权重：0.824887,偏置为：0.568770
# 第79次优化的参数权重：0.819933,偏置为：0.569988
# 第80次优化的参数权重：0.820876,偏置为：0.574019
# 第81次优化的参数权重：0.821887,偏置为：0.578452
# 第82次优化的参数权重：0.817273,偏置为：0.579615
# 第83次优化的参数权重：0.817458,偏置为：0.582651
# 第84次优化的参数权重：0.813858,偏置为：0.583382
# 第85次优化的参数权重：0.815563,偏置为：0.587408
# 第86次优化的参数权重：0.815384,偏置为：0.590752
# 第87次优化的参数权重：0.812821,偏置为：0.592875
# 第88次优化的参数权重：0.812680,偏置为：0.595421
# 第89次优化的参数权重：0.809155,偏置为：0.596366
# 第90次优化的参数权重：0.808311,偏置为：0.599233
# 第91次优化的参数权重：0.804704,偏置为：0.600353
# 第92次优化的参数权重：0.805776,偏置为：0.604675
# 第93次优化的参数权重：0.802350,偏置为：0.606466
# 第94次优化的参数权重：0.801291,偏置为：0.609186
# 第95次优化的参数权重：0.801697,偏置为：0.611655
# 第96次优化的参数权重：0.800806,偏置为：0.614832
# 第97次优化的参数权重：0.798175,偏置为：0.617050
# 第98次优化的参数权重：0.799582,偏置为：0.620812
# 第99次优化的参数权重：0.793206,偏置为：0.620162
# 第100次优化的参数权重：0.796678,偏置为：0.624799
# 第101次优化的参数权重：0.795682,偏置为：0.627349
# 第102次优化的参数权重：0.792388,偏置为：0.627805
# 第103次优化的参数权重：0.791609,偏置为：0.631037
# 第104次优化的参数权重：0.791078,偏置为：0.633389
# 第105次优化的参数权重：0.789271,偏置为：0.634940
# 第106次优化的参数权重：0.789796,偏置为：0.637589
# 第107次优化的参数权重：0.788296,偏置为：0.639326
# 第108次优化的参数权重：0.785890,偏置为：0.641081
# 第109次优化的参数权重：0.786121,偏置为：0.643533
# 第110次优化的参数权重：0.787212,偏置为：0.646296
# 第111次优化的参数权重：0.783109,偏置为：0.645994
# 第112次优化的参数权重：0.782086,偏置为：0.646878
# 第113次优化的参数权重：0.780827,偏置为：0.647559
# 第114次优化的参数权重：0.777247,偏置为：0.647927
# 第115次优化的参数权重：0.778211,偏置为：0.650693
# 第116次优化的参数权重：0.778338,偏置为：0.652770
# 第117次优化的参数权重：0.779038,偏置为：0.655234
# 第118次优化的参数权重：0.776954,偏置为：0.656458
# 第119次优化的参数权重：0.777448,偏置为：0.659295
# 第120次优化的参数权重：0.777909,偏置为：0.661765
# 第121次优化的参数权重：0.773387,偏置为：0.661551
# 第122次优化的参数权重：0.772721,偏置为：0.663256
# 第123次优化的参数权重：0.775739,偏置为：0.666597
# 第124次优化的参数权重：0.772434,偏置为：0.667068
# 第125次优化的参数权重：0.771279,偏置为：0.668010
# 第126次优化的参数权重：0.770275,偏置为：0.669552
# 第127次优化的参数权重：0.770414,偏置为：0.671167
# 第128次优化的参数权重：0.769451,偏置为：0.671853
# 第129次优化的参数权重：0.768345,偏置为：0.673333
# 第130次优化的参数权重：0.766094,偏置为：0.674283
# 第131次优化的参数权重：0.766005,偏置为：0.676088
# 第132次优化的参数权重：0.764455,偏置为：0.676783
# 第133次优化的参数权重：0.765819,偏置为：0.678721
# 第134次优化的参数权重：0.764752,偏置为：0.679969
# 第135次优化的参数权重：0.763564,偏置为：0.681505
# 第136次优化的参数权重：0.763657,偏置为：0.683648
# 第137次优化的参数权重：0.762407,偏置为：0.684835
# 第138次优化的参数权重：0.760949,偏置为：0.685719
# 第139次优化的参数权重：0.759001,偏置为：0.686742
# 第140次优化的参数权重：0.760976,偏置为：0.689559
# 第141次优化的参数权重：0.760415,偏置为：0.690990
# 第142次优化的参数权重：0.757479,偏置为：0.691522
# 第143次优化的参数权重：0.757137,偏置为：0.693267
# 第144次优化的参数权重：0.756574,偏置为：0.694408
# 第145次优化的参数权重：0.754934,偏置为：0.694976
# 第146次优化的参数权重：0.756316,偏置为：0.697312
# 第147次优化的参数权重：0.753856,偏置为：0.697832
# 第148次优化的参数权重：0.754214,偏置为：0.699556
# 第149次优化的参数权重：0.753639,偏置为：0.700718
# 第150次优化的参数权重：0.751725,偏置为：0.701209
# 第151次优化的参数权重：0.752664,偏置为：0.703460
# 第152次优化的参数权重：0.751724,偏置为：0.704399
# 第153次优化的参数权重：0.751023,偏置为：0.705819
# 第154次优化的参数权重：0.750948,偏置为：0.707264
# 第155次优化的参数权重：0.750020,偏置为：0.708149
# 第156次优化的参数权重：0.747707,偏置为：0.708049
# 第157次优化的参数权重：0.748367,偏置为：0.709840
# 第158次优化的参数权重：0.748113,偏置为：0.710973
# 第159次优化的参数权重：0.747959,偏置为：0.712398
# 第160次优化的参数权重：0.748175,偏置为：0.713692
# 第161次优化的参数权重：0.747384,偏置为：0.714601
# 第162次优化的参数权重：0.747140,偏置为：0.715810
# 第163次优化的参数权重：0.746596,偏置为：0.716789
# 第164次优化的参数权重：0.745795,偏置为：0.717502
# 第165次优化的参数权重：0.744793,偏置为：0.718383
# 第166次优化的参数权重：0.744484,偏置为：0.719474
# 第167次优化的参数权重：0.743984,偏置为：0.720525
# 第168次优化的参数权重：0.742185,偏置为：0.720665
# 第169次优化的参数权重：0.741683,偏置为：0.721448
# 第170次优化的参数权重：0.740920,偏置为：0.722132
# 第171次优化的参数权重：0.742130,偏置为：0.723884
# 第172次优化的参数权重：0.740689,偏置为：0.724028
# 第173次优化的参数权重：0.740827,偏置为：0.725094
# 第174次优化的参数权重：0.740668,偏置为：0.725906
# 第175次优化的参数权重：0.740112,偏置为：0.726845
# 第176次优化的参数权重：0.739835,偏置为：0.727680
# 第177次优化的参数权重：0.739266,偏置为：0.728372
# 第178次优化的参数权重：0.739311,偏置为：0.729468
# 第179次优化的参数权重：0.737879,偏置为：0.729775
# 第180次优化的参数权重：0.736722,偏置为：0.730104
# 第181次优化的参数权重：0.735616,偏置为：0.730769
# 第182次优化的参数权重：0.736413,偏置为：0.732293
# 第183次优化的参数权重：0.736143,偏置为：0.733311
# 第184次优化的参数权重：0.735805,偏置为：0.734426
# 第185次优化的参数权重：0.734568,偏置为：0.735035
# 第186次优化的参数权重：0.734020,偏置为：0.735615
# 第187次优化的参数权重：0.734890,偏置为：0.736917
# 第188次优化的参数权重：0.733230,偏置为：0.736983
# 第189次优化的参数权重：0.732918,偏置为：0.737863
# 第190次优化的参数权重：0.732720,偏置为：0.738570
# 第191次优化的参数权重：0.732471,偏置为：0.739306
# 第192次优化的参数权重：0.731927,偏置为：0.739760
# 第193次优化的参数权重：0.731887,偏置为：0.740738
# 第194次优化的参数权重：0.731224,偏置为：0.741003
# 第195次优化的参数权重：0.731451,偏置为：0.742001
# 第196次优化的参数权重：0.730464,偏置为：0.742519
# 第197次优化的参数权重：0.730092,偏置为：0.743077
# 第198次优化的参数权重：0.730401,偏置为：0.743837
# 第199次优化的参数权重：0.729272,偏置为：0.744269
# 第200次优化的参数权重：0.729737,偏置为：0.745266
# 第201次优化的参数权重：0.729342,偏置为：0.746215
# 第202次优化的参数权重：0.728872,偏置为：0.746739
# 第203次优化的参数权重：0.728175,偏置为：0.747122
# 第204次优化的参数权重：0.727544,偏置为：0.747461
# 第205次优化的参数权重：0.727814,偏置为：0.748182
# 第206次优化的参数权重：0.728001,偏置为：0.748946
# 第207次优化的参数权重：0.727625,偏置为：0.749432
# 第208次优化的参数权重：0.726476,偏置为：0.749600
# 第209次优化的参数权重：0.727076,偏置为：0.750649
# 第210次优化的参数权重：0.726325,偏置为：0.751127
# 第211次优化的参数权重：0.725794,偏置为：0.751635
# 第212次优化的参数权重：0.725058,偏置为：0.752053
# 第213次优化的参数权重：0.725050,偏置为：0.752798
# 第214次优化的参数权重：0.725444,偏置为：0.753733
# 第215次优化的参数权重：0.724682,偏置为：0.754066
# 第216次优化的参数权重：0.724461,偏置为：0.754581
# 第217次优化的参数权重：0.723735,偏置为：0.754843
# 第218次优化的参数权重：0.723730,偏置为：0.755512
# 第219次优化的参数权重：0.723961,偏置为：0.756321
# 第220次优化的参数权重：0.722696,偏置为：0.756252
# 第221次优化的参数权重：0.722268,偏置为：0.756629
# 第222次优化的参数权重：0.723017,偏置为：0.757571
# 第223次优化的参数权重：0.722499,偏置为：0.757978
# 第224次优化的参数权重：0.722355,偏置为：0.758402
# 第225次优化的参数权重：0.722526,偏置为：0.759163
# 第226次优化的参数权重：0.721773,偏置为：0.759285
# 第227次优化的参数权重：0.722035,偏置为：0.760010
# 第228次优化的参数权重：0.720950,偏置为：0.760028
# 第229次优化的参数权重：0.721556,偏置为：0.761056
# 第230次优化的参数权重：0.720966,偏置为：0.761407
# 第231次优化的参数权重：0.720483,偏置为：0.761702
# 第232次优化的参数权重：0.720918,偏置为：0.762565
# 第233次优化的参数权重：0.719834,偏置为：0.762511
# 第234次优化的参数权重：0.719957,偏置为：0.762987
# 第235次优化的参数权重：0.720100,偏置为：0.763710
# 第236次优化的参数权重：0.719262,偏置为：0.763740
# 第237次优化的参数权重：0.719136,偏置为：0.764265
# 第238次优化的参数权重：0.719377,偏置为：0.764909
# 第239次优化的参数权重：0.718868,偏置为：0.765213
# 第240次优化的参数权重：0.718882,偏置为：0.765678
# 第241次优化的参数权重：0.718593,偏置为：0.766049
# 第242次优化的参数权重：0.718373,偏置为：0.766367
# 第243次优化的参数权重：0.718219,偏置为：0.766690
# 第244次优化的参数权重：0.717210,偏置为：0.766752
# 第245次优化的参数权重：0.717910,偏置为：0.767672
# 第246次优化的参数权重：0.717197,偏置为：0.767787
# 第247次优化的参数权重：0.716833,偏置为：0.768165
# 第248次优化的参数权重：0.716590,偏置为：0.768543
# 第249次优化的参数权重：0.716878,偏置为：0.769196
# 第250次优化的参数权重：0.716335,偏置为：0.769344
# 第251次优化的参数权重：0.715937,偏置为：0.769549
# 第252次优化的参数权重：0.716339,偏置为：0.770133
# 第253次优化的参数权重：0.716260,偏置为：0.770513
# 第254次优化的参数权重：0.715698,偏置为：0.770734
# 第255次优化的参数权重：0.715397,偏置为：0.770945
# 第256次优化的参数权重：0.715927,偏置为：0.771722
# 第257次优化的参数权重：0.715491,偏置为：0.771873
# 第258次优化的参数权重：0.714886,偏置为：0.771971
# 第259次优化的参数权重：0.714984,偏置为：0.772379
# 第260次优化的参数权重：0.714826,偏置为：0.772717
# 第261次优化的参数权重：0.714740,偏置为：0.773132
# 第262次优化的参数权重：0.714261,偏置为：0.773342
# 第263次优化的参数权重：0.714067,偏置为：0.773631
# 第264次优化的参数权重：0.713988,偏置为：0.773919
# 第265次优化的参数权重：0.713614,偏置为：0.774037
# 第266次优化的参数权重：0.713638,偏置为：0.774391
# 第267次优化的参数权重：0.713547,偏置为：0.774718
# 第268次优化的参数权重：0.712845,偏置为：0.774762
# 第269次优化的参数权重：0.713224,偏置为：0.775347
# 第270次优化的参数权重：0.713429,偏置为：0.775756
# 第271次优化的参数权重：0.712970,偏置为：0.775854
# 第272次优化的参数权重：0.712960,偏置为：0.776134
# 第273次优化的参数权重：0.713063,偏置为：0.776558
# 第274次优化的参数权重：0.713383,偏置为：0.777089
# 第275次优化的参数权重：0.713018,偏置为：0.777185
# 第276次优化的参数权重：0.712288,偏置为：0.777134
# 第277次优化的参数权重：0.712184,偏置为：0.777399
# 第278次优化的参数权重：0.711934,偏置为：0.777572
# 第279次优化的参数权重：0.711685,偏置为：0.777838
# 第280次优化的参数权重：0.711450,偏置为：0.778013
# 第281次优化的参数权重：0.711415,偏置为：0.778294
# 第282次优化的参数权重：0.711750,偏置为：0.778920
# 第283次优化的参数权重：0.711551,偏置为：0.779197
# 第284次优化的参数权重：0.711034,偏置为：0.779257
# 第285次优化的参数权重：0.711077,偏置为：0.779631
# 第286次优化的参数权重：0.710561,偏置为：0.779657
# 第287次优化的参数权重：0.710812,偏置为：0.780041
# 第288次优化的参数权重：0.710435,偏置为：0.780107
# 第289次优化的参数权重：0.710560,偏置为：0.780496
# 第290次优化的参数权重：0.710357,偏置为：0.780658
# 第291次优化的参数权重：0.710347,偏置为：0.780881
# 第292次优化的参数权重：0.710235,偏置为：0.781139
# 第293次优化的参数权重：0.710176,偏置为：0.781421
# 第294次优化的参数权重：0.710027,偏置为：0.781628
# 第295次优化的参数权重：0.710000,偏置为：0.781837
# 第296次优化的参数权重：0.709986,偏置为：0.782151
# 第297次优化的参数权重：0.709836,偏置为：0.782272
# 第298次优化的参数权重：0.709720,偏置为：0.782455
# 第299次优化的参数权重：0.709285,偏置为：0.782536
# 第300次优化的参数权重：0.709240,偏置为：0.782746
# 第301次优化的参数权重：0.709247,偏置为：0.783042
# 第302次优化的参数权重：0.709074,偏置为：0.783145
# 第303次优化的参数权重：0.708702,偏置为：0.783154
# 第304次优化的参数权重：0.708707,偏置为：0.783437
# 第305次优化的参数权重：0.708736,偏置为：0.783630
# 第306次优化的参数权重：0.708409,偏置为：0.783659
# 第307次优化的参数权重：0.708457,偏置为：0.783982
# 第308次优化的参数权重：0.708407,偏置为：0.784215
# 第309次优化的参数权重：0.708355,偏置为：0.784381
# 第310次优化的参数权重：0.708405,偏置为：0.784705
# 第311次优化的参数权重：0.708433,偏置为：0.784965
# 第312次优化的参数权重：0.708021,偏置为：0.784969
# 第313次优化的参数权重：0.707964,偏置为：0.785167
# 第314次优化的参数权重：0.707611,偏置为：0.785210
# 第315次优化的参数权重：0.707749,偏置为：0.785463
# 第316次优化的参数权重：0.707853,偏置为：0.785670
# 第317次优化的参数权重：0.707459,偏置为：0.785650
# 第318次优化的参数权重：0.707525,偏置为：0.785878
# 第319次优化的参数权重：0.707454,偏置为：0.786019
# 第320次优化的参数权重：0.707439,偏置为：0.786188
# 第321次优化的参数权重：0.707473,偏置为：0.786425
# 第322次优化的参数权重：0.707246,偏置为：0.786511
# 第323次优化的参数权重：0.707024,偏置为：0.786637
# 第324次优化的参数权重：0.706938,偏置为：0.786803
# 第325次优化的参数权重：0.707043,偏置为：0.787093
# 第326次优化的参数权重：0.706825,偏置为：0.787217
# 第327次优化的参数权重：0.706881,偏置为：0.787428
# 第328次优化的参数权重：0.706802,偏置为：0.787569
# 第329次优化的参数权重：0.706474,偏置为：0.787576
# 第330次优化的参数权重：0.706514,偏置为：0.787760
# 第331次优化的参数权重：0.706528,偏置为：0.787975
# 第332次优化的参数权重：0.706375,偏置为：0.788095
# 第333次优化的参数权重：0.706157,偏置为：0.788191
# 第334次优化的参数权重：0.706208,偏置为：0.788386
# 第335次优化的参数权重：0.706335,偏置为：0.788633
# 第336次优化的参数权重：0.706299,偏置为：0.788785
# 第337次优化的参数权重：0.706176,偏置为：0.788913
# 第338次优化的参数权重：0.705844,偏置为：0.788943
# 第339次优化的参数权重：0.705836,偏置为：0.789103
# 第340次优化的参数权重：0.705785,偏置为：0.789264
# 第341次优化的参数权重：0.705542,偏置为：0.789324
# 第342次优化的参数权重：0.705382,偏置为：0.789394
# 第343次优化的参数权重：0.705482,偏置为：0.789628
# 第344次优化的参数权重：0.705491,偏置为：0.789843
# 第345次优化的参数权重：0.705561,偏置为：0.790003
# 第346次优化的参数权重：0.705265,偏置为：0.790008
# 第347次优化的参数权重：0.705330,偏置为：0.790271
# 第348次优化的参数权重：0.705156,偏置为：0.790310
# 第349次优化的参数权重：0.705246,偏置为：0.790526
# 第350次优化的参数权重：0.705028,偏置为：0.790539
# 第351次优化的参数权重：0.704840,偏置为：0.790606
# 第352次优化的参数权重：0.704938,偏置为：0.790824
# 第353次优化的参数权重：0.704882,偏置为：0.790929
# 第354次优化的参数权重：0.704880,偏置为：0.791049
# 第355次优化的参数权重：0.704682,偏置为：0.791083
# 第356次优化的参数权重：0.704715,偏置为：0.791222
# 第357次优化的参数权重：0.704615,偏置为：0.791287
# 第358次优化的参数权重：0.704660,偏置为：0.791405
# 第359次优化的参数权重：0.704524,偏置为：0.791467
# 第360次优化的参数权重：0.704458,偏置为：0.791577
# 第361次优化的参数权重：0.704491,偏置为：0.791726
# 第362次优化的参数权重：0.704469,偏置为：0.791808
# 第363次优化的参数权重：0.704447,偏置为：0.791934
# 第364次优化的参数权重：0.704304,偏置为：0.791971
# 第365次优化的参数权重：0.704213,偏置为：0.792062
# 第366次优化的参数权重：0.704274,偏置为：0.792253
# 第367次优化的参数权重：0.704152,偏置为：0.792285
# 第368次优化的参数权重：0.704042,偏置为：0.792331
# 第369次优化的参数权重：0.703879,偏置为：0.792334
# 第370次优化的参数权重：0.704022,偏置为：0.792553
# 第371次优化的参数权重：0.703811,偏置为：0.792558
# 第372次优化的参数权重：0.703940,偏置为：0.792753
# 第373次优化的参数权重：0.704007,偏置为：0.792883
# 第374次优化的参数权重：0.703840,偏置为：0.792910
# 第375次优化的参数权重：0.703644,偏置为：0.792920
# 第376次优化的参数权重：0.703744,偏置为：0.793068
# 第377次优化的参数权重：0.703656,偏置为：0.793128
# 第378次优化的参数权重：0.703605,偏置为：0.793211
# 第379次优化的参数权重：0.703581,偏置为：0.793272
# 第380次优化的参数权重：0.703556,偏置为：0.793350
# 第381次优化的参数权重：0.703536,偏置为：0.793443
# 第382次优化的参数权重：0.703425,偏置为：0.793471
# 第383次优化的参数权重：0.703457,偏置为：0.793587
# 第384次优化的参数权重：0.703356,偏置为：0.793642
# 第385次优化的参数权重：0.703467,偏置为：0.793823
# 第386次优化的参数权重：0.703293,偏置为：0.793834
# 第387次优化的参数权重：0.703226,偏置为：0.793897
# 第388次优化的参数权重：0.703202,偏置为：0.793975
# 第389次优化的参数权重：0.703089,偏置为：0.794010
# 第390次优化的参数权重：0.703180,偏置为：0.794162
# 第391次优化的参数权重：0.703013,偏置为：0.794167
# 第392次优化的参数权重：0.703154,偏置为：0.794341
# 第393次优化的参数权重：0.702961,偏置为：0.794315
# 第394次优化的参数权重：0.703002,偏置为：0.794426
# 第395次优化的参数权重：0.702933,偏置为：0.794483
# 第396次优化的参数权重：0.702966,偏置为：0.794576
# 第397次优化的参数权重：0.702901,偏置为：0.794640
# 第398次优化的参数权重：0.702875,偏置为：0.794704
# 第399次优化的参数权重：0.702894,偏置为：0.794767
# 第400次优化的参数权重：0.702838,偏置为：0.794833
# 第401次优化的参数权重：0.702757,偏置为：0.794864
# 第402次优化的参数权重：0.702751,偏置为：0.794945
# 第403次优化的参数权重：0.702653,偏置为：0.794989
# 第404次优化的参数权重：0.702667,偏置为：0.795065
# 第405次优化的参数权重：0.702676,偏置为：0.795132
# 第406次优化的参数权重：0.702584,偏置为：0.795166
# 第407次优化的参数权重：0.702608,偏置为：0.795260
# 第408次优化的参数权重：0.702529,偏置为：0.795291
# 第409次优化的参数权重：0.702382,偏置为：0.795281
# 第410次优化的参数权重：0.702441,偏置为：0.795406
# 第411次优化的参数权重：0.702427,偏置为：0.795453
# 第412次优化的参数权重：0.702331,偏置为：0.795474
# 第413次优化的参数权重：0.702414,偏置为：0.795580
# 第414次优化的参数权重：0.702371,偏置为：0.795629
# 第415次优化的参数权重：0.702300,偏置为：0.795662
# 第416次优化的参数权重：0.702270,偏置为：0.795719
# 第417次优化的参数权重：0.702178,偏置为：0.795745
# 第418次优化的参数权重：0.702243,偏置为：0.795852
# 第419次优化的参数权重：0.702155,偏置为：0.795863
# 第420次优化的参数权重：0.702206,偏置为：0.795955
# 第421次优化的参数权重：0.702200,偏置为：0.796009
# 第422次优化的参数权重：0.702097,偏置为：0.796009
# 第423次优化的参数权重：0.702088,偏置为：0.796060
# 第424次优化的参数权重：0.701979,偏置为：0.796073
# 第425次优化的参数权重：0.702031,偏置为：0.796155
# 第426次优化的参数权重：0.702015,偏置为：0.796203
# 第427次优化的参数权重：0.701988,偏置为：0.796232
# 第428次优化的参数权重：0.701964,偏置为：0.796279
# 第429次优化的参数权重：0.702008,偏置为：0.796361
# 第430次优化的参数权重：0.701885,偏置为：0.796364
# 第431次优化的参数权重：0.701890,偏置为：0.796435
# 第432次优化的参数权重：0.701917,偏置为：0.796513
# 第433次优化的参数权重：0.701836,偏置为：0.796519
# 第434次优化的参数权重：0.701823,偏置为：0.796554
# 第435次优化的参数权重：0.701833,偏置为：0.796621
# 第436次优化的参数权重：0.701790,偏置为：0.796657
# 第437次优化的参数权重：0.701712,偏置为：0.796665
# 第438次优化的参数权重：0.701761,偏置为：0.796743
# 第439次优化的参数权重：0.701736,偏置为：0.796773
# 第440次优化的参数权重：0.701678,偏置为：0.796793
# 第441次优化的参数权重：0.701645,偏置为：0.796823
# 第442次优化的参数权重：0.701644,偏置为：0.796858
# 第443次优化的参数权重：0.701682,偏置为：0.796929
# 第444次优化的参数权重：0.701679,偏置为：0.796982
# 第445次优化的参数权重：0.701606,偏置为：0.796999
# 第446次优化的参数权重：0.701586,偏置为：0.797034
# 第447次优化的参数权重：0.701555,偏置为：0.797066
# 第448次优化的参数权重：0.701538,偏置为：0.797097
# 第449次优化的参数权重：0.701512,偏置为：0.797125
# 第450次优化的参数权重：0.701521,偏置为：0.797172
# 第451次优化的参数权重：0.701503,偏置为：0.797207
# 第452次优化的参数权重：0.701489,偏置为：0.797238
# 第453次优化的参数权重：0.701503,偏置为：0.797285
# 第454次优化的参数权重：0.701470,偏置为：0.797308
# 第455次优化的参数权重：0.701438,偏置为：0.797329
# 第456次优化的参数权重：0.701436,偏置为：0.797366
# 第457次优化的参数权重：0.701399,偏置为：0.797395
# 第458次优化的参数权重：0.701356,偏置为：0.797404
# 第459次优化的参数权重：0.701377,偏置为：0.797450
# 第460次优化的参数权重：0.701300,偏置为：0.797448
# 第461次优化的参数权重：0.701354,偏置为：0.797516
# 第462次优化的参数权重：0.701350,偏置为：0.797555
# 第463次优化的参数权重：0.701342,偏置为：0.797595
# 第464次优化的参数权重：0.701342,偏置为：0.797638
# 第465次优化的参数权重：0.701305,偏置为：0.797645
# 第466次优化的参数权重：0.701242,偏置为：0.797644
# 第467次优化的参数权重：0.701221,偏置为：0.797671
# 第468次优化的参数权重：0.701239,偏置为：0.797714
# 第469次优化的参数权重：0.701218,偏置为：0.797740
# 第470次优化的参数权重：0.701201,偏置为：0.797770
# 第471次优化的参数权重：0.701218,偏置为：0.797821
# 第472次优化的参数权重：0.701162,偏置为：0.797819
# 第473次优化的参数权重：0.701143,偏置为：0.797839
# 第474次优化的参数权重：0.701123,偏置为：0.797865
# 第475次优化的参数权重：0.701127,偏置为：0.797895
# 第476次优化的参数权重：0.701150,偏置为：0.797938
# 第477次优化的参数权重：0.701136,偏置为：0.797966
# 第478次优化的参数权重：0.701125,偏置为：0.797985
# 第479次优化的参数权重：0.701045,偏置为：0.797978
# 第480次优化的参数权重：0.701082,偏置为：0.798024
# 第481次优化的参数权重：0.701060,偏置为：0.798034
# 第482次优化的参数权重：0.701060,偏置为：0.798057
# 第483次优化的参数权重：0.701039,偏置为：0.798077
# 第484次优化的参数权重：0.700971,偏置为：0.798068
# 第485次优化的参数权重：0.700976,偏置为：0.798104
# 第486次优化的参数权重：0.700998,偏置为：0.798150
# 第487次优化的参数权重：0.700953,偏置为：0.798149
# 第488次优化的参数权重：0.700994,偏置为：0.798207
# 第489次优化的参数权重：0.700974,偏置为：0.798218
# 第490次优化的参数权重：0.700875,偏置为：0.798205
# 第491次优化的参数权重：0.700938,偏置为：0.798262
# 第492次优化的参数权重：0.700915,偏置为：0.798279
# 第493次优化的参数权重：0.700913,偏置为：0.798311
# 第494次优化的参数权重：0.700928,偏置为：0.798343
# 第495次优化的参数权重：0.700896,偏置为：0.798357
# 第496次优化的参数权重：0.700875,偏置为：0.798368
# 第497次优化的参数权重：0.700870,偏置为：0.798392
# 第498次优化的参数权重：0.700848,偏置为：0.798404
# 第499次优化的参数权重：0.700857,偏置为：0.798433

# %% [markdown]
# # 模型保存与加载

# %%
def myregression3():
    """
    线性回归预测
    """
    
    with tf.variable_scope("data"):
        #1.准备数据 x：特征值【100,1】 y：目标值【100】
        x = tf.random_normal([100,1],mean=1.75,stddev=0.5,name='x_data')

        #矩阵相乘必须是二维的（预设好的数据）
        y_true = tf.matmul(x,[[0.7]]) + 0.8
    
    with tf.variable_scope("model"):
        #2.建立线性回归模型 1个特征，1个权重  一个偏置 y= x*w + b
        #随机给一个权重和偏置的值，去计算损失，然后在当前状态下优化
        #用变量定义才能优化（数据可变）
        #trainable决定训练过程中的值是否被改变
        weight = tf.Variable(tf.random_normal([1,1],mean=0.0,stddev=1.0),name='w',trainable=True)


        bias = tf.Variable(0.0,name='b',trainable=True)
        y_predict = tf.matmul(x,weight) + bias

    
    with tf.variable_scope("loss"):
        #3.建立损失函数，均分误差
        loss = tf.reduce_mean(tf.square(y_true - y_predict))

    with tf.variable_scope("optimizer"):
        #4.梯度下降优化损失:leaning_rate：0~1，2,3...
        train_op = tf.train.GradientDescentOptimizer(0.1).minimize(loss)
    
    #1.收集tensor
    tf.summary.scalar('losses',loss)
    tf.summary.histogram('weights',weight)
    #定义合并tensor的op
    merged = tf.summary.merge_all()
    
    
    #定义一个初始化变量的op
    init_op = tf.global_variables_initializer()
    
    #定义一个保存模型的实例
    saver = tf.train.Saver()
    
    
    #通过会话运行程序
    with tf.Session() as sess:
        #初始化变量
        sess.run(init_op)
        
        #打印随机最先初始化的权重和偏置
        print("随机初始化的参数权重：%f,偏置为：%f" %(weight.eval(),bias.eval() ))
        
        #建立事件文件
        fileWriter = tf.summary.FileWriter('./summary/',graph=sess.graph)
        
        #加载模型，覆盖模型当中随机定义的参数，从上一次训练的参数结果开始
        ckpt = tf.train.get_checkpoint_state('./ckpt/')
        print(ckpt)
        print(ckpt.model_checkpoint_path)
        if ckpt and ckpt.model_checkpoint_path:
            saver.restore(sess, ckpt.model_checkpoint_path)
        
        #循环训练，运行优化
        for i in range(500):
            sess.run(train_op)

            #运行合并的tensor(用于tensorboard显示)
            summary = sess.run(merged)
            fileWriter.add_summary(summary,i)

            print("第%d次优化的参数权重：%f,偏置为：%f" %(i,weight.eval(),bias.eval() ))
            
        saver.save(sess,'./ckpt/model')
               
        
        
myregression3()
# Out:
# 随机初始化的参数权重：-0.776513,偏置为：0.000000
# model_checkpoint_path: "./ckpt/model"
# all_model_checkpoint_paths: "./ckpt/model"
#
# ./ckpt/model
# INFO:tensorflow:Restoring parameters from ./ckpt/model
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#
# ~/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#
# ~/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#
# NotFoundError: Key model_47/b not found in checkpoint
# 	 [[{{node save_43/RestoreV2}}]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# ~/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1285         sess.run(self.saver_def.restore_op_name,
# -> 1286                  {self.saver_def.filename_tensor_name: save_path})
#    1287     except errors.NotFoundError as err:
#
# ~/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#
# ~/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#
# ~/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#
# ~/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1369       message = error_interpolation.interpolate(message, self._graph)
# -> 1370       raise type(e)(node_def, op, message)
#    1371
#
# NotFoundError: Key model_47/b not found in checkpoint
# 	 [[node save_43/RestoreV2 (defined at <ipython-input-111-57236a452229>:44) ]]
#
# Original stack trace for 'save_43/RestoreV2':
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 563, in start
#     self.io_loop.start()
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 438, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1451, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2855, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2881, in _run_cell
#     return runner(coro)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3058, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3249, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-111-57236a452229>", line 79, in <module>
#     myregression3()
#   File "<ipython-input-111-57236a452229>", line 44, in myregression3
#     saver = tf.train.Saver()
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 825, in __init__
#     self.build()
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 837, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 875, in _build
#     build_restore=build_restore)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 508, in _build_internal
#     restore_sequentially, reshape)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 328, in _AddRestoreOps
#     restore_sequentially)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 575, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1696, in restore_v2
#     name=name)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 788, in _apply_op_helper
#     op_def=op_def)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3616, in create_op
#     op_def=op_def)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 2005, in __init__
#     self._traceback = tf_stack.extract_stack()
#
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# ~/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1295       try:
# -> 1296         names_to_keys = object_graph_key_mapping(save_path)
#    1297       except errors.NotFoundError:
#
# ~/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py in object_graph_key_mapping(checkpoint_path)
#    1613   reader = pywrap_tensorflow.NewCheckpointReader(checkpoint_path)
# -> 1614   object_graph_string = reader.get_tensor(trackable.OBJECT_GRAPH_PROTO_KEY)
#    1615   object_graph_proto = (trackable_object_graph_pb2.TrackableObjectGraph())
#
# ~/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in get_tensor(self, tensor_str)
#     677
# --> 678       return CheckpointReader_GetTensor(self, compat.as_bytes(tensor_str))
#     679
#
# NotFoundError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-111-57236a452229> in <module>
#      77
#      78
# ---> 79 myregression3()
#      80
#
# <ipython-input-111-57236a452229> in myregression3()
#      61         print(ckpt.model_checkpoint_path)
#      62         if ckpt and ckpt.model_checkpoint_path:
# ---> 63             saver.restore(sess, ckpt.model_checkpoint_path)
#      64
#      65         #循环训练，运行优化
#
# ~/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1300         # a helpful message (b/110263146)
#    1301         raise _wrap_restore_error_with_msg(
# -> 1302             err, "a Variable name or other graph key that is missing")
#    1303
#    1304       # This is an object-based checkpoint. We'll print a warning and then do
#
# NotFoundError: Restoring from checkpoint failed. This is most likely due to a Variable name or other graph key that is missing from the checkpoint. Please ensure that you have not altered the graph expected based on the checkpoint. Original error:
#
# Key model_47/b not found in checkpoint
# 	 [[node save_43/RestoreV2 (defined at <ipython-input-111-57236a452229>:44) ]]
#
# Original stack trace for 'save_43/RestoreV2':
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 563, in start
#     self.io_loop.start()
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 438, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1451, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2855, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2881, in _run_cell
#     return runner(coro)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3058, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3249, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-111-57236a452229>", line 79, in <module>
#     myregression3()
#   File "<ipython-input-111-57236a452229>", line 44, in myregression3
#     saver = tf.train.Saver()
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 825, in __init__
#     self.build()
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 837, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 875, in _build
#     build_restore=build_restore)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 508, in _build_internal
#     restore_sequentially, reshape)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 328, in _AddRestoreOps
#     restore_sequentially)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 575, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1696, in restore_v2
#     name=name)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 788, in _apply_op_helper
#     op_def=op_def)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3616, in create_op
#     op_def=op_def)
#   File "/home/tang/mnt/F/学习/人工智能/venv/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 2005, in __init__
#     self._traceback = tf_stack.extract_stack()

# %% [markdown]
# # 定义命令行参数
#     * 1.首先定义有哪些参数需要在运行时指定
#     * 2.程序中获取定义命令行参数
#
# * 如下通过命令行执行
#     * python xx.py --max_step=500

# %%
#参数：名字，默认值，说明
tf.app.flags.DEFINE_integer("max_step",100,'模型训练的步数')
tf.app.flags.DEFINE_string("model_dir",'','模型文件的加载路径')

#定义获取命令行参数名字
FLAGS = tf.app.flags.FLAGS

def myregression4():
    """
    线性回归预测
    """
    
    with tf.variable_scope("data"):
        #1.准备数据 x：特征值【100,1】 y：目标值【100】
        x = tf.random_normal([100,1],mean=1.75,stddev=0.5,name='x_data')

        #矩阵相乘必须是二维的（预设好的数据）
        y_true = tf.matmul(x,[[0.7]]) + 0.8
    
    with tf.variable_scope("model"):
        #2.建立线性回归模型 1个特征，1个权重  一个偏置 y= x*w + b
        #随机给一个权重和偏置的值，去计算损失，然后在当前状态下优化
        #用变量定义才能优化（数据可变）
        #trainable决定训练过程中的值是否被改变
        weight = tf.Variable(tf.random_normal([1,1],mean=0.0,stddev=1.0),name='w',trainable=True)


        bias = tf.Variable(0.0,name='b',trainable=True)
        y_predict = tf.matmul(x,weight) + bias

    
    with tf.variable_scope("loss"):
        #3.建立损失函数，均分误差
        loss = tf.reduce_mean(tf.square(y_true - y_predict))

    with tf.variable_scope("optimizer"):
        #4.梯度下降优化损失:leaning_rate：0~1，2,3...
        train_op = tf.train.GradientDescentOptimizer(0.1).minimize(loss)
    
    #1.收集tensor
    tf.summary.scalar('losses',loss)
    tf.summary.histogram('weights',weight)
    #定义合并tensor的op
    merged = tf.summary.merge_all()
    
    
    #定义一个初始化变量的op
    init_op = tf.global_variables_initializer()
    
    #通过会话运行程序
    with tf.Session() as sess:
        #初始化变量
        sess.run(init_op)
        
        #打印随机最先初始化的权重和偏置
        print("随机初始化的参数权重：%f,偏置为：%f" %(weight.eval(),bias.eval() ))
        
        #建立事件文件
        fileWriter = tf.summary.FileWriter('./summary/',graph=sess.graph)
        
        #循环训练，运行优化
        for i in range(FLAGS.max_step):
            sess.run(train_op)
            
            #运行合并的tensor(用于tensorboard显示)
            summary = sess.run(merged)
            fileWriter.add_summary(summary,i)
            
            print("第%d次优化的参数权重：%f,偏置为：%f" %(i,weight.eval(),bias.eval() ))

       
        
        
myregression4()
